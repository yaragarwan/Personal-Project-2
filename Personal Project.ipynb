# %%
from pandas import DataFrame
import pandas as pd

# %%
data= pd.read_csv("order_products__train.csv")

# %%
data.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# # Q1) Whats the product ID that's added to cart the most?

# %%
data.sort_values(by='add_to_cart_order', ascending=False, na_position='first')
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1138788   2813632       41771                 80          1
# 567831    1395075       21641                 80          0
# 1138787   2813632       14862                 79          0
# 567830    1395075       47766                 79          1
# 567829    1395075       45063                 78          1
# 1138786   2813632        6187                 78          0
# 1138785   2813632       38400                 77          1
# 388834     949182       27086                 77          1
# 567828    1395075        1709                 77          0
# 139744     341238          79                 76          0
# 1138784   2813632       30806                 76          0
# 388833     949182       27845                 76          1
# 1161024   2869702       12440                 76          1
# 567827    1395075       44497                 76          1
# 567826    1395075       21868                 75          1
# ...

# %%
mostadded= data.loc[data['add_to_cart_order'] == 80]

# %%
mostadded
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 567831    1395075       21641                 80          0
# 1138788   2813632       41771                 80          1

# %%
mostadded.product_id
# Out:
# 567831     21641
# 1138788    41771
# Name: product_id, dtype: int64

# %% [markdown]
# ## Answer:
# ### Product ID's 21641 and 41771 are added to the cart the most.

# %% [markdown]
# # Q2) What are these products' names?

# %%
# we need to read the csv file for the product names to merge it with the current data. 
names=pd.read_csv("products.csv")

# %%
names.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
data = pd.merge(data, names, on='product_id', how='left')
data.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1
#
#                                     product_name  aisle_id  department_id
# 0                               Bulgarian Yogurt       120             16
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 2                          Organic Celery Hearts        83              4
# 3                                 Cucumber Kirby        83              4
# 4           Lightly Smoked Sardines in Olive Oil        95             15

# %%
mostadded= data.loc[data['add_to_cart_order'] == 80]

# %%
mostadded
# Out:
#          order_id  product_id  add_to_cart_order  reordered  \
# 567831    1395075       21641                 80          0
# 1138788   2813632       41771                 80          1
#
#                               product_name  aisle_id  department_id
# 567831           Mixed Nuts Lightly Salted       117             19
# 1138788  Fresh European Style Baby Spinach       123              4

# %% [markdown]
# ## Answer: The most added items are "Mixed Nuts Lightly Salted" and "Fresh European Style Baby Spinach."
